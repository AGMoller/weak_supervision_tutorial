# %% [markdown]
# # Machine Learning with Limited Data (2023): Exam Submission
#
# Made by Anders Giovanni Møller, PhD at IT University of Copenhagen.
#
# Email: agmo@itu.dk

# %%
# Imports
# %load_ext autoreload
# %autoreload 2

import re
import os

import pandas as pd

import nltk
import spacy

from textblob import TextBlob
from textblob.taggers import PatternTagger

import skweak

from scripts.skweak_ner_eval import evaluate
from scripts.utils import load_data_split, get_frequent_words, tag_all, penntreebank2universal, compute_recall, compute_num_conflicts

pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Task
#
# For this specific task, I'll be training a POS-tagger in Danish, using the Danish UD dataset. The data has been extracted and put into the `corpus/` folder.
#
# For labels, I will make labelling functions for determiners, numerals, proper nouns, adjectives, and nouns.

# %%
all_labels = ["DET", "NUM", "PROPN", "ADJ", "NOUN"]

# Load training data
train_docs = load_data_split("train", "UD_Danish-DDT", all_labels)

# Display first 3 docs
for doc in train_docs[:3]:
    skweak.utils.display_entities(doc)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">På
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fredag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  har
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SID
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROPN</span>
# </mark>
#  inviteret til
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reception
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SID-huset
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anledning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  af at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     formanden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kjeld
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROPN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christensen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROPN</span>
# </mark>
#  går ind i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DET</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     glade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tressere
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Eller slet og ret
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tykke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ</span>
# </mark>
#  og
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fede
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ</span>
# </mark>
#  i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mere
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ</span>
# </mark>
#  eller
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mindre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     grad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , som
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     en
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DET</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     enkelt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ</span>
# </mark>
#  udtrykker det. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Under
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rejser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  og
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ophold
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     udlandet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  følger
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sygeplejersker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  og
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hjælpere
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  med. </div></span>

# %% [markdown]
# # Labelling Functions

# %% [markdown]
# ### Determiners LFs
#
# I found a list of Danish determiners and put them into a json file.

# %%
tries = skweak.gazetteers.extract_json_data("det.json")
det_lf = skweak.gazetteers.GazetteerAnnotator("determiners", tries, case_sensitive=False)
# Out:
# Extracting data from det.json
# Populating trie for class DET (number: 21)

# %% [markdown]
# ###  Numerals LFs

# %%
# Use a regular expression pattern to look for digits
def num_detector(doc):
    for token in doc:
        if re.search("\d+", token.text):
            yield token.i, token.i + 1, "NUM"

# Check if the token is the word of a number from 1 to 10
def num_word_detector(doc):
    for token in doc:
        if token.text.lower() in ["én", "to", "tre", "fire", "fem", "seks", "syv", "otte", "ni", "ti"]:
            yield token.i, token.i + 1, "NUM"

num_lf1 = skweak.heuristics.FunctionAnnotator("numerals1", num_detector)
num_lf2 = skweak.heuristics.FunctionAnnotator("numerals2", num_word_detector)

# %% [markdown]
# ### Adjective LFs

# %%
# Look for words that end with a suffix typical for adjectives
def adj_detector_suffixes_danish(doc):
    danish_adj_suffixes = ("-lig", "-sk", "-bar", "-fuld", "-løs", "-vis", "-en", "-som", "-agtig")
    for token in doc:
        if len(token.text) > 3 and token.text.endswith(danish_adj_suffixes):
            yield token.i, token.i + 1, "ADJ"

# Look for words that start with a prefix typical for adjectives
def adj_detector_prefixes_danish(doc):
    danish_adj_prefixes = ("u", "anti", "over", "under", "mis", "efter", "gen")
    for token in doc:
        if len(token.text) > 3 and token.text.lower().startswith(danish_adj_prefixes):
            yield token.i, token.i + 1, "ADJ"

# Look for words that are preceded by a form of the verb "to be"
def adj_detector_synt1_danish(doc):
    weak_labels = ["O"] * len(doc)
    for span in doc.spans["determiners"]:
        weak_labels[span.start] = span.label_

    for token in doc[1:]:
        if not token.is_punct:
            prev = doc[token.i - 1].text.lower()
            if prev in ["er", "var", "være", "bliver", "blev"] and (
                    not token.text.endswith("ende")) and weak_labels[token.i] == "O":
                yield token.i, token.i + 1, "ADJ"

# Look for words that are preceded by a determiner or a number
def adj_detector_synt2_danish(doc):
    weak_labels = ["O"] * len(doc)

    for span in doc.spans["determiners"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["numerals1"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["numerals2"]:
        weak_labels[span.start] = span.label_

    for token in doc[1:]:
        if not token.is_punct:
            if weak_labels[token.i - 1] != "O":
                yield token.i, token.i + 1, "ADJ"


adj_lf1 = skweak.heuristics.FunctionAnnotator("adjs1", adj_detector_suffixes_danish)
adj_lf2 = skweak.heuristics.FunctionAnnotator("adjs2", adj_detector_prefixes_danish)
adj_lf3 = skweak.heuristics.FunctionAnnotator("adjs3", adj_detector_synt1_danish)
adj_lf4 = skweak.heuristics.FunctionAnnotator("adjs4", adj_detector_synt2_danish)

# %% [markdown]
# ### Proper nouns LFs

# %%
# Check if the fist letter of a word or the whole word is capitalized
def propn_detector(doc):
    for token in doc:
        if token.i == 0:
            # For the first word of a sentence, check if all letters are capitalized
            if token.text.isupper():
                yield token.i, token.i + 1, "PROPN"
        else:
            if token.text.isupper() or token.text[0].isupper():
                yield token.i, token.i + 1, "PROPN"


propn_lf = skweak.heuristics.FunctionAnnotator("proper_nouns", propn_detector)

# %% [markdown]
# ### Noun LFs

# %%
# Look for words that end with a suffix typical for nouns
def noun_detector_suffixes_danish(doc):
    danish_noun_suffixes = (
        "-hed", "-dom", "-else", "-ing", "-ion",
        "-skab", "-eri", "-itet", "-ance", "-ens",
        "-age", "-ør", "-ist"
    )
    for token in doc:
        if len(token.text) > 3 and token.text.endswith(danish_noun_suffixes):
            yield token.i, token.i + 1, "NOUN"


# Look for words that start with a prefix typical for nouns
def noun_detector_prefixes_danish(doc):
    danish_prefixes = (
        "over", "under", "mis", "gen", "efter", "for", "u", "be", "til", "op", "af", "an", "ud", "fore", "om"
    )
    for token in doc:
        if len(token.text) > 3 and token.text.lower().startswith(danish_prefixes):
            yield token.i, token.i + 1, "NOUN"

# # If the previous word is labeld as DET, NUM or ADJ, then the current word is an noun
def noun_detector_synt(doc):
    weak_labels = ["O"] * len(doc)

    for span in doc.spans["determiners"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["numerals1"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["numerals2"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["adjs1"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["adjs2"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["adjs3"]:
        weak_labels[span.start] = span.label_

    for span in doc.spans["adjs4"]:
        weak_labels[span.start] = span.label_

    for token in doc[1:]:
        if not token.is_punct:
            if weak_labels[token.i - 1] != "O":
                yield token.i, token.i + 1, "NOUN"

noun_lf1 = skweak.heuristics.FunctionAnnotator("nouns1", noun_detector_suffixes_danish)
noun_lf2 = skweak.heuristics.FunctionAnnotator("nouns2", noun_detector_prefixes_danish)
noun_lf3 = skweak.heuristics.FunctionAnnotator("nouns3", noun_detector_synt)

# %% [markdown]
# # Apply LFs

# %%
# Put all LFs in a list
lfs = [
    det_lf, 
    num_lf1, num_lf2, propn_lf,
    adj_lf1, adj_lf2, adj_lf3, adj_lf4,
    noun_lf1, noun_lf2, noun_lf3
]


train_docs = tag_all(train_docs, lfs)

# %%
# Print some of the assigned weak labels
for doc in train_docs[:3]:
    skweak.utils.display_entities(doc, ["determiners", "nouns1", "nouns2", "nouns3", "adjs1", "adjs2", "adjs3", "adjs4", "proper_nouns", "numerals1", "numerals2"])
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">På fredag har
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SID
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROPN</span>
# </mark>
#  inviteret til reception i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SID-huset
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROPN</span>
# </mark>
#  i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anledning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  af at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     formanden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kjeld
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROPN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christensen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROPN</span>
# </mark>
#  går ind i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DET</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     glade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tressere
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Eller slet og ret tykke og fede i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mere
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DET</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eller
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mindre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  grad, som
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     en
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DET</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     enkelt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     udtrykker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     det
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Under
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rejser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  og
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ophold
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     udlandet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     følger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  sygeplejersker og hjælpere med. </div></span>

# %% [markdown]
# ### Train HMM and Majority

# %%
# HMM
hmm = skweak.aggregation.HMM("hmm", all_labels)
hmm.fit(train_docs)

# Majority voting
mv = skweak.aggregation.MajorityVoter("mv", all_labels)

# Apply LFs, HMM and MV to the test docs
test_docs = load_data_split("test", "UD_Danish-DDT", all_labels)
test_docs = tag_all(test_docs, lfs + [mv, hmm])
# Out:
# Starting iteration 1
# Number of processed documents: 1000
# Number of processed documents: 2000
# Number of processed documents: 3000
# Number of processed documents: 4000
# Finished E-step with 4080 documents
# Starting iteration 2
#          1 -114027.17492093             +nan
# Number of processed documents: 1000
# Number of processed documents: 2000
# Number of processed documents: 3000
# Number of processed documents: 4000
# Finished E-step with 4080 documents
# Starting iteration 3
#          2 -104557.26234337   +9469.91257756
# Number of processed documents: 1000
# Number of processed documents: 2000
# Number of processed documents: 3000
# Number of processed documents: 4000
# Finished E-step with 4080 documents
# Starting iteration 4
#          3 -100172.26492503   +4384.99741834
# Number of processed documents: 1000
# Number of processed documents: 2000
# Number of processed documents: 3000
# Number of processed documents: 4000
# Finished E-step with 4080 documents
#          4  -96757.66263620   +3414.60228883

# %%
df = evaluate(test_docs, all_labels, [
    "determiners", "proper_nouns", "nouns1", "nouns2", "nouns3", "adjs1", "adjs2", "adjs3", "adjs4", "numerals1", "numerals2"
])

df
# Out:
#                                   tok_precision  tok_recall  tok_f1 tok_cee  \
# label    proportion model
# ADJ      17.4 %     adjs1                 0.000       0.000   0.000
#                     adjs2                 0.085       0.033   0.048
#                     adjs3                 0.188       0.066   0.098
#                     adjs4                 0.274       0.337   0.302
#                     determiners           0.000       0.000   0.000
#                     nouns1                0.000       0.000   0.000
#                     nouns2                0.000       0.000   0.000
#                     nouns3                0.000       0.000   0.000
#                     numerals1             0.000       0.000   0.000
#                     numerals2             0.000       0.000   0.000
#                     proper_nouns          0.000       0.000   0.000
# DET      13.6 %     adjs1                 0.000       0.000   0.000
#                     adjs2                 0.000       0.000   0.000
#                     adjs3                 0.000       0.000   0.000
#                     adjs4                 0.000       0.000   0.000
#                     determiners           0.579       0.790   0.668
#                     nouns1                0.000       0.000   0.000
#                     nouns2                0.000       0.000   0.000
#                     nouns3                0.000       0.000   0.000
#                     numerals1             0.000       0.000   0.000
#                     numerals2             0.000       0.000   0.000
#                     proper_nouns          0.000       0.000   0.000
# NOUN     49.8 %     adjs1                 0.000       0.000   0.000
#                     adjs2                 0.000       0.000   0.000
#                     adjs3                 0.000       0.000   0.000
#                     adjs4                 0.000       0.000   0.000
#                     determiners           0.000       0.000   0.000
#                     nouns1                0.000       0.000   0.000
#                     nouns2                0.352       0.131   0.190
#                     nouns3                0.318       0.305   0.312
#                     numerals1             0.000       0.000   0.000
#                     numerals2             0.000       0.000   0.000
#                     proper_nouns          0.000       0.000   0.000
# NUM      4.2 %      adjs1                 0.000       0.000   0.000
#                     adjs2                 0.000       0.000   0.000
#                     adjs3                 0.000       0.000   0.000
#                     adjs4                 0.000       0.000   0.000
#                     determiners           0.000       0.000   0.000
#                     nouns1                0.000       0.000   0.000
#                     nouns2                0.000       0.000   0.000
#                     nouns3                0.000       0.000   0.000
#                     numerals1             0.821       0.719   0.766
#                     numerals2             0.905       0.248   0.390
#                     proper_nouns          0.000       0.000   0.000
# PROPN    15.0 %     adjs1                 0.000       0.000   0.000
#                     adjs2                 0.000       0.000   0.000
#                     adjs3                 0.000       0.000   0.000
#                     adjs4                 0.000       0.000   0.000
#                     determiners           0.000       0.000   0.000
#                     nouns1                0.000       0.000   0.000
#                     nouns2                0.000       0.000   0.000
#                     nouns3                0.000       0.000   0.000
#                     numerals1             0.000       0.000   0.000
#                     numerals2             0.000       0.000   0.000
#                     proper_nouns          0.635       0.944   0.760
# macro               adjs1                 0.000       0.000   0.000
#                     adjs2                 0.017       0.007   0.010
#                     adjs3                 0.038       0.013   0.020
#                     adjs4                 0.055       0.067   0.060
#                     determiners           0.116       0.158   0.134
#                     nouns1                0.000       0.000   0.000
#                     nouns2                0.070       0.026   0.038
#                     nouns3                0.064       0.061   0.062
#                     numerals1             0.164       0.144   0.154
#                     numerals2             0.181       0.050   0.078
#                     proper_nouns          0.127       0.189   0.152
# micro               adjs1                 0.000       0.000   0.000  13.172
#                     adjs2                 0.085       0.006   0.012  13.172
#                     adjs3                 0.188       0.011   0.020  13.172
#                     adjs4                 0.274       0.059   0.098  13.172
#                     determiners           0.579       0.108   0.182  13.172
#                     nouns1                0.000       0.000   0.000  13.172
#                     nouns2                0.352       0.065   0.110  13.172
#                     nouns3                0.318       0.152   0.206  13.172
#                     numerals1             0.821       0.030   0.058  13.172
#                     numerals2             0.905       0.010   0.020  13.172
#                     proper_nouns          0.635       0.142   0.232  13.172
# weighted            adjs1                 0.000       0.000   0.000
#                     adjs2                 0.015       0.006   0.008
#                     adjs3                 0.033       0.011   0.016
#                     adjs4                 0.048       0.059   0.052
#                     determiners           0.079       0.108   0.092
#                     nouns1                0.000       0.000   0.000
#                     nouns2                0.175       0.065   0.094
#                     nouns3                0.158       0.152   0.154
#                     numerals1             0.034       0.030   0.032
#                     numerals2             0.038       0.010   0.016
#                     proper_nouns          0.095       0.142   0.114
#
#                                  tok_acc coverage  ent_precision  ent_recall  \
# label    proportion model
# ADJ      17.4 %     adjs1                                  0.000       0.000
#                     adjs2                                  0.085       0.033
#                     adjs3                                  0.188       0.066
#                     adjs4                                  0.274       0.337
#                     determiners                            0.000       0.000
#                     nouns1                                 0.000       0.000
#                     nouns2                                 0.000       0.000
#                     nouns3                                 0.000       0.000
#                     numerals1                              0.000       0.000
#                     numerals2                              0.000       0.000
#                     proper_nouns                           0.000       0.000
# DET      13.6 %     adjs1                                  0.000       0.000
#                     adjs2                                  0.000       0.000
#                     adjs3                                  0.000       0.000
#                     adjs4                                  0.000       0.000
#                     determiners                            0.579       0.790
#                     nouns1                                 0.000       0.000
#                     nouns2                                 0.000       0.000
#                     nouns3                                 0.000       0.000
#                     numerals1                              0.000       0.000
#                     numerals2                              0.000       0.000
#                     proper_nouns                           0.000       0.000
# NOUN     49.8 %     adjs1                                  0.000       0.000
#                     adjs2                                  0.000       0.000
#                     adjs3                                  0.000       0.000
#                     adjs4                                  0.000       0.000
#                     determiners                            0.000       0.000
#                     nouns1                                 0.000       0.000
#                     nouns2                                 0.352       0.131
#                     nouns3                                 0.318       0.305
#                     numerals1                              0.000       0.000
#                     numerals2                              0.000       0.000
#                     proper_nouns                           0.000       0.000
# NUM      4.2 %      adjs1                                  0.000       0.000
#                     adjs2                                  0.000       0.000
#                     adjs3                                  0.000       0.000
#                     adjs4                                  0.000       0.000
#                     determiners                            0.000       0.000
#                     nouns1                                 0.000       0.000
#                     nouns2                                 0.000       0.000
#                     nouns3                                 0.000       0.000
#                     numerals1                              0.821       0.719
#                     numerals2                              0.905       0.248
#                     proper_nouns                           0.000       0.000
# PROPN    15.0 %     adjs1                                  0.000       0.000
#                     adjs2                                  0.000       0.000
#                     adjs3                                  0.000       0.000
#                     adjs4                                  0.000       0.000
#                     determiners                            0.000       0.000
#                     nouns1                                 0.000       0.000
#                     nouns2                                 0.000       0.000
#                     nouns3                                 0.000       0.000
#                     numerals1                              0.000       0.000
#                     numerals2                              0.000       0.000
#                     proper_nouns                           0.635       0.944
# macro               adjs1                                  0.000       0.000
#                     adjs2                                  0.017       0.007
#                     adjs3                                  0.038       0.013
#                     adjs4                                  0.055       0.067
#                     determiners                            0.116       0.158
#                     nouns1                                 0.000       0.000
#                     nouns2                                 0.070       0.026
#                     nouns3                                 0.064       0.061
#                     numerals1                              0.164       0.144
#                     numerals2                              0.181       0.050
#                     proper_nouns                           0.127       0.189
# micro               adjs1          0.635      0.0          0.000       0.000
#                     adjs2          0.635    0.067          0.085       0.006
#                     adjs3          0.635    0.061          0.188       0.011
#                     adjs4          0.635    0.215          0.274       0.059
#                     determiners    0.635    0.186          0.579       0.108
#                     nouns1         0.635      0.0          0.000       0.000
#                     nouns2         0.635    0.185          0.352       0.065
#                     nouns3         0.635    0.477          0.318       0.152
#                     numerals1      0.635    0.037          0.821       0.030
#                     numerals2      0.635    0.011          0.905       0.010
#                     proper_nouns   0.635    0.223          0.635       0.142
# weighted            adjs1                                  0.000       0.000
#                     adjs2                                  0.015       0.006
#                     adjs3                                  0.033       0.011
#                     adjs4                                  0.048       0.059
#                     determiners                            0.079       0.108
#                     nouns1                                 0.000       0.000
#                     nouns2                                 0.175       0.065
#                     nouns3                                 0.158       0.152
#                     numerals1                              0.034       0.030
#                     numerals2                              0.038       0.010
#                     proper_nouns                           0.095       0.142
#
#                                   ent_f1
# label    proportion model
# ADJ      17.4 %     adjs1          0.000
#                     adjs2          0.048
#                     adjs3          0.098
#                     adjs4          0.302
#                     determiners    0.000
#                     nouns1         0.000
#                     nouns2         0.000
#                     nouns3         0.000
#                     numerals1      0.000
#                     numerals2      0.000
#                     proper_nouns   0.000
# DET      13.6 %     adjs1          0.000
#                     adjs2          0.000
#                     adjs3          0.000
#                     adjs4          0.000
#                     determiners    0.668
#                     nouns1         0.000
#                     nouns2         0.000
#                     nouns3         0.000
#                     numerals1      0.000
#                     numerals2      0.000
#                     proper_nouns   0.000
# NOUN     49.8 %     adjs1          0.000
#                     adjs2          0.000
#                     adjs3          0.000
#                     adjs4          0.000
#                     determiners    0.000
#                     nouns1         0.000
#                     nouns2         0.190
#                     nouns3         0.312
#                     numerals1      0.000
#                     numerals2      0.000
#                     proper_nouns   0.000
# NUM      4.2 %      adjs1          0.000
#                     adjs2          0.000
#                     adjs3          0.000
#                     adjs4          0.000
#                     determiners    0.000
#                     nouns1         0.000
#                     nouns2         0.000
#                     nouns3         0.000
#                     numerals1      0.766
#                     numerals2      0.390
#                     proper_nouns   0.000
# PROPN    15.0 %     adjs1          0.000
#                     adjs2          0.000
#                     adjs3          0.000
#                     adjs4          0.000
#                     determiners    0.000
#                     nouns1         0.000
#                     nouns2         0.000
#                     nouns3         0.000
#                     numerals1      0.000
#                     numerals2      0.000
#                     proper_nouns   0.760
# macro               adjs1          0.000
#                     adjs2          0.010
#                     adjs3          0.020
#                     adjs4          0.060
#                     determiners    0.134
#                     nouns1         0.000
#                     nouns2         0.038
#                     nouns3         0.062
#                     numerals1      0.154
#                     numerals2      0.078
#                     proper_nouns   0.152
# micro               adjs1          0.000
#                     adjs2          0.012
#                     adjs3          0.020
#                     adjs4          0.098
#                     determiners    0.182
#                     nouns1         0.000
#                     nouns2         0.110
#                     nouns3         0.206
#                     numerals1      0.058
#                     numerals2      0.020
#                     proper_nouns   0.232
# weighted            adjs1          0.000
#                     adjs2          0.008
#                     adjs3          0.016
#                     adjs4          0.052
#                     determiners    0.092
#                     nouns1         0.000
#                     nouns2         0.094
#                     nouns3         0.154
#                     numerals1      0.032
#                     numerals2      0.016
#                     proper_nouns   0.114

# %% [markdown]
# ### Evaluation
#
# Generally, we observe that the determiners, numerals, and proper nouns labelling functions work well, achieving relatively high F1 scores. Nouns and adjectives are more difficult POS tags.

# %% [markdown]
# ### Aggregator Performance

# %%
df = evaluate(test_docs, all_labels, ["mv", "hmm"])
df
# Out:
#                            tok_precision  tok_recall  tok_f1 tok_cee tok_acc  \
# label    proportion model
# ADJ      17.4 %     hmm            0.280       0.342   0.308
#                     mv             0.193       0.042   0.068
# DET      13.6 %     hmm            0.603       0.780   0.680
#                     mv             0.580       0.673   0.624
# NOUN     49.8 %     hmm            0.376       0.154   0.218
#                     mv             0.365       0.225   0.278
# NUM      4.2 %      hmm            0.902       0.660   0.762
#                     mv             0.886       0.712   0.790
# PROPN    15.0 %     hmm            0.788       0.513   0.622
#                     mv             0.666       0.820   0.736
# macro               hmm            0.590       0.490   0.536
#                     mv             0.538       0.494   0.516
# micro               hmm            0.481       0.347   0.404   7.684   0.671
#                     mv             0.505       0.364   0.424   5.888   0.658
# weighted            hmm            0.474       0.347   0.400
#                     mv             0.431       0.364   0.394
#
#                           coverage  ent_precision  ent_recall  ent_f1
# label    proportion model
# ADJ      17.4 %     hmm                     0.280       0.342   0.308
#                     mv                      0.193       0.042   0.068
# DET      13.6 %     hmm                     0.603       0.780   0.680
#                     mv                      0.580       0.673   0.624
# NOUN     49.8 %     hmm                     0.376       0.154   0.218
#                     mv                      0.365       0.225   0.278
# NUM      4.2 %      hmm                     0.902       0.660   0.762
#                     mv                      0.886       0.712   0.790
# PROPN    15.0 %     hmm                     0.788       0.513   0.622
#                     mv                      0.666       0.820   0.736
# macro               hmm                     0.590       0.490   0.536
#                     mv                      0.538       0.494   0.516
# micro               hmm       0.72          0.481       0.347   0.404
#                     mv       0.722          0.505       0.364   0.424
# weighted            hmm                     0.474       0.347   0.400
#                     mv                      0.431       0.364   0.394

# %% [markdown]
# For adjectives and determiners, the HMM model performs better than majority voting. For numerals, they are more or less comparable, whereas majority voting is best for nouns and proper nouns.

# %% [markdown]
# ## Evaluate on other languages

# %% [markdown]
# #### Gaelic Scottish (unrelated)
#
# From the numbers below, we see that numerals and proper nouns are actually found occationally, while adjectives, nouns, and determiners are not detected with the model.

# %%
test_docs_scottish = load_data_split("test", "UD_Scottish_Gaelic-ARCOSG", all_labels)
test_docs_scottish = tag_all(test_docs_scottish, lfs + [mv, hmm])

df_scottish = evaluate(test_docs_scottish, all_labels, ["mv", "hmm", "determiners", "proper_nouns", "nouns1", "nouns2", "nouns3", "adjs1", "adjs2", "numerals1", "numerals2", "adjs3", "adjs4"])
df_scottish.loc[['ADJ', 'DET', 'NOUN', 'NUM', 'PROPN']]
# Out:
#                                tok_precision  tok_recall  tok_f1 tok_cee  \
# label proportion model
# ADJ   10.2 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.028       0.005   0.008
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.042       0.005   0.008
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.042       0.005   0.008
#                  mv                    0.000       0.000   0.000
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# DET   18.6 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.000       0.000   0.000
#                  mv                    0.000       0.000   0.000
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NOUN  54.6 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.282       0.010   0.020
#                  mv                    0.219       0.018   0.034
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.301       0.023   0.042
#                  nouns3                0.195       0.015   0.028
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NUM   4.0 %      adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   1.000       0.129   0.228
#                  mv                    1.000       0.206   0.342
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             1.000       0.265   0.418
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# PROPN 12.6 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.555       0.574   0.564
#                  mv                    0.540       0.744   0.626
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.553       0.802   0.654
#
#                               tok_acc coverage  ent_precision  ent_recall  \
# label proportion model
# ADJ   10.2 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.028       0.005
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.042       0.005
#                  determiners                            0.000       0.000
#                  hmm                                    0.042       0.005
#                  mv                                     0.000       0.000
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# DET   18.6 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.000       0.000
#                  mv                                     0.000       0.000
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NOUN  54.6 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.282       0.010
#                  mv                                     0.219       0.018
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.301       0.023
#                  nouns3                                 0.195       0.015
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NUM   4.0 %      adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    1.000       0.129
#                  mv                                     1.000       0.206
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              1.000       0.265
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# PROPN 12.6 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.555       0.574
#                  mv                                     0.540       0.744
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.553       0.802
#
#                                ent_f1
# label proportion model
# ADJ   10.2 %     adjs1          0.000
#                  adjs2          0.008
#                  adjs3          0.000
#                  adjs4          0.008
#                  determiners    0.000
#                  hmm            0.008
#                  mv             0.000
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# DET   18.6 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.000
#                  mv             0.000
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NOUN  54.6 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.020
#                  mv             0.034
#                  nouns1         0.000
#                  nouns2         0.042
#                  nouns3         0.028
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NUM   4.0 %      adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.228
#                  mv             0.342
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.418
#                  numerals2      0.000
#                  proper_nouns   0.000
# PROPN 12.6 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.564
#                  mv             0.626
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.654

# %% [markdown]
# #### Turkish (unrelated)
#
# The numbers below show that proper nouns are detected relatively frequently, while adjectives, numerals, and nouns sparsely are captured. Determiners are never found.

# %%
test_docs_turkish = load_data_split("test", "UD_Turkish-IMST", all_labels)
test_docs_turkish = tag_all(test_docs_turkish, lfs + [mv, hmm])

df_turkish = evaluate(test_docs_turkish, all_labels, ["mv", "hmm", "determiners", "proper_nouns", "nouns1", "nouns2", "nouns3", "adjs1", "adjs2", "numerals1", "numerals2", "adjs3", "adjs4"])
df_turkish.loc[['ADJ', 'DET', 'NOUN', 'NUM', 'PROPN']]
# Out:
#                                tok_precision  tok_recall  tok_f1 tok_cee  \
# label proportion model
# ADJ   20.2 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.238       0.033   0.058
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.224       0.024   0.044
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.220       0.024   0.044
#                  mv                    0.000       0.000   0.000
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# DET   3.9 %      adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.000       0.000   0.000
#                  mv                    0.000       0.000   0.000
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NOUN  59.5 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.311       0.030   0.054
#                  mv                    0.319       0.042   0.074
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.247       0.032   0.056
#                  nouns3                0.370       0.037   0.068
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NUM   7.7 %      adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   1.000       0.017   0.034
#                  mv                    1.000       0.017   0.034
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             1.000       0.017   0.034
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# PROPN 8.8 %      adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.487       0.558   0.520
#                  mv                    0.498       0.681   0.576
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.497       0.748   0.598
#
#                               tok_acc coverage  ent_precision  ent_recall  \
# label proportion model
# ADJ   20.2 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.238       0.033
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.224       0.024
#                  determiners                            0.000       0.000
#                  hmm                                    0.220       0.024
#                  mv                                     0.000       0.000
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# DET   3.9 %      adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.000       0.000
#                  mv                                     0.000       0.000
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NOUN  59.5 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.311       0.030
#                  mv                                     0.319       0.042
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.247       0.032
#                  nouns3                                 0.370       0.037
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NUM   7.7 %      adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    1.000       0.017
#                  mv                                     1.000       0.017
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              1.000       0.017
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# PROPN 8.8 %      adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.487       0.558
#                  mv                                     0.498       0.681
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.497       0.748
#
#                                ent_f1
# label proportion model
# ADJ   20.2 %     adjs1          0.000
#                  adjs2          0.058
#                  adjs3          0.000
#                  adjs4          0.044
#                  determiners    0.000
#                  hmm            0.044
#                  mv             0.000
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# DET   3.9 %      adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.000
#                  mv             0.000
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NOUN  59.5 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.054
#                  mv             0.074
#                  nouns1         0.000
#                  nouns2         0.056
#                  nouns3         0.068
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NUM   7.7 %      adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.034
#                  mv             0.034
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.034
#                  numerals2      0.000
#                  proper_nouns   0.000
# PROPN 8.8 %      adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.520
#                  mv             0.576
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.598

# %% [markdown]
# #### Spanish (related)
#
# We see how proper nouns and numerals are frequently found, and nouns are captured relatively often considering the substantial proportion.

# %%
test_docs_spanish = load_data_split("test", "UD_Spanish-GSD", all_labels)
test_docs_spanish = tag_all(test_docs_spanish, lfs + [mv, hmm])

df_spanish = evaluate(test_docs_spanish, all_labels, ["mv", "hmm", "determiners", "proper_nouns", "nouns1", "nouns2", "nouns3", "adjs1", "adjs2", "numerals1", "numerals2", "adjs3", "adjs4"])
df_spanish.loc[['ADJ', 'DET', 'NOUN', 'NUM', 'PROPN']]
# Out:
# /Users/agmo/projects/phd_courses/weak_supervision_tutorial/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:2916: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
#                                tok_precision  tok_recall  tok_f1 tok_cee  \
# label proportion model
# ADJ   12.3 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.269       0.031   0.056
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.022       0.039   0.028
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.023       0.039   0.028
#                  mv                    0.000       0.000   0.000
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# DET   27.3 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.000       0.000   0.000
#                  mv                    0.000       0.000   0.000
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NOUN  41.0 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.428       0.163   0.236
#                  mv                    0.450       0.159   0.234
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.379       0.031   0.058
#                  nouns3                0.321       0.308   0.314
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NUM   4.2 %      adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.913       0.367   0.524
#                  mv                    0.940       0.476   0.632
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.951       0.769   0.850
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# PROPN 15.2 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.705       0.341   0.460
#                  mv                    0.676       0.556   0.610
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.700       0.901   0.788
#
#                               tok_acc coverage  ent_precision  ent_recall  \
# label proportion model
# ADJ   12.3 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.269       0.031
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.022       0.039
#                  determiners                            0.000       0.000
#                  hmm                                    0.023       0.039
#                  mv                                     0.000       0.000
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# DET   27.3 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.000       0.000
#                  mv                                     0.000       0.000
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NOUN  41.0 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.428       0.163
#                  mv                                     0.450       0.159
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.379       0.031
#                  nouns3                                 0.321       0.308
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NUM   4.2 %      adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.913       0.367
#                  mv                                     0.940       0.476
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.951       0.769
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# PROPN 15.2 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.705       0.341
#                  mv                                     0.676       0.556
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.700       0.901
#
#                                ent_f1
# label proportion model
# ADJ   12.3 %     adjs1          0.000
#                  adjs2          0.056
#                  adjs3          0.000
#                  adjs4          0.028
#                  determiners    0.000
#                  hmm            0.028
#                  mv             0.000
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# DET   27.3 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.000
#                  mv             0.000
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NOUN  41.0 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.236
#                  mv             0.234
#                  nouns1         0.000
#                  nouns2         0.058
#                  nouns3         0.314
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NUM   4.2 %      adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.524
#                  mv             0.632
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.850
#                  numerals2      0.000
#                  proper_nouns   0.000
# PROPN 15.2 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.460
#                  mv             0.610
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.788

# %% [markdown]
# #### Swedish (related)
#
# We observe how our model performs relatively well on Swedish, which is very related to Danish. Most of the labels obtain high F1 scores, except for nouns, which was also found to be challenging on Danish.

# %%
test_docs_swedish = load_data_split("test", "UD_Swedish-LinES", all_labels)
test_docs_swedish = tag_all(test_docs_swedish, lfs + [mv, hmm])

df_swedish = evaluate(test_docs_swedish, all_labels, ["mv", "hmm", "determiners", "proper_nouns", "nouns1", "nouns2", "nouns3", "adjs1", "adjs2", "numerals1", "numerals2", "adjs3", "adjs4"])
df_swedish.loc[['ADJ', 'DET', 'NOUN', 'NUM', 'PROPN']]
# Out:
#                                tok_precision  tok_recall  tok_f1 tok_cee  \
# label proportion model
# ADJ   21.5 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.120       0.031   0.050
#                  adjs3                 0.261       0.024   0.044
#                  adjs4                 0.322       0.277   0.298
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.323       0.277   0.298
#                  mv                    0.312       0.021   0.040
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# DET   15.0 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.564       0.666   0.610
#                  hmm                   0.581       0.659   0.618
#                  mv                    0.549       0.589   0.568
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NOUN  51.6 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.309       0.114   0.166
#                  mv                    0.273       0.153   0.196
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.196       0.060   0.092
#                  nouns3                0.280       0.220   0.246
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.000       0.000   0.000
# NUM   1.9 %      adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.471       0.374   0.416
#                  mv                    0.547       0.383   0.450
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.816       0.374   0.512
#                  numerals2             0.204       0.103   0.136
#                  proper_nouns          0.000       0.000   0.000
# PROPN 10.1 %     adjs1                 0.000       0.000   0.000
#                  adjs2                 0.000       0.000   0.000
#                  adjs3                 0.000       0.000   0.000
#                  adjs4                 0.000       0.000   0.000
#                  determiners           0.000       0.000   0.000
#                  hmm                   0.798       0.352   0.488
#                  mv                    0.742       0.772   0.756
#                  nouns1                0.000       0.000   0.000
#                  nouns2                0.000       0.000   0.000
#                  nouns3                0.000       0.000   0.000
#                  numerals1             0.000       0.000   0.000
#                  numerals2             0.000       0.000   0.000
#                  proper_nouns          0.704       0.846   0.768
#
#                               tok_acc coverage  ent_precision  ent_recall  \
# label proportion model
# ADJ   21.5 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.120       0.031
#                  adjs3                                  0.261       0.024
#                  adjs4                                  0.322       0.277
#                  determiners                            0.000       0.000
#                  hmm                                    0.323       0.277
#                  mv                                     0.312       0.021
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# DET   15.0 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.564       0.666
#                  hmm                                    0.581       0.659
#                  mv                                     0.549       0.589
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NOUN  51.6 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.309       0.114
#                  mv                                     0.273       0.153
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.196       0.060
#                  nouns3                                 0.280       0.220
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.000       0.000
# NUM   1.9 %      adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.471       0.374
#                  mv                                     0.547       0.383
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.816       0.374
#                  numerals2                              0.204       0.103
#                  proper_nouns                           0.000       0.000
# PROPN 10.1 %     adjs1                                  0.000       0.000
#                  adjs2                                  0.000       0.000
#                  adjs3                                  0.000       0.000
#                  adjs4                                  0.000       0.000
#                  determiners                            0.000       0.000
#                  hmm                                    0.798       0.352
#                  mv                                     0.742       0.772
#                  nouns1                                 0.000       0.000
#                  nouns2                                 0.000       0.000
#                  nouns3                                 0.000       0.000
#                  numerals1                              0.000       0.000
#                  numerals2                              0.000       0.000
#                  proper_nouns                           0.704       0.846
#
#                                ent_f1
# label proportion model
# ADJ   21.5 %     adjs1          0.000
#                  adjs2          0.050
#                  adjs3          0.044
#                  adjs4          0.298
#                  determiners    0.000
#                  hmm            0.298
#                  mv             0.040
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# DET   15.0 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.610
#                  hmm            0.618
#                  mv             0.568
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NOUN  51.6 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.166
#                  mv             0.196
#                  nouns1         0.000
#                  nouns2         0.092
#                  nouns3         0.246
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.000
# NUM   1.9 %      adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.416
#                  mv             0.450
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.512
#                  numerals2      0.136
#                  proper_nouns   0.000
# PROPN 10.1 %     adjs1          0.000
#                  adjs2          0.000
#                  adjs3          0.000
#                  adjs4          0.000
#                  determiners    0.000
#                  hmm            0.488
#                  mv             0.756
#                  nouns1         0.000
#                  nouns2         0.000
#                  nouns3         0.000
#                  numerals1      0.000
#                  numerals2      0.000
#                  proper_nouns   0.768

# %% [markdown]
# ## Token Classification Model

# %% [markdown]
# #### Convert data to correct format

# %%
import pandas as pd


def transform_train(docs, aggregation_model="mv"): # also possible to use HMM

  for doc in docs:
      doc.set_ents(doc.spans.get(aggregation_model, []))

  df = []
  for sidx, doc in enumerate(docs):
      for tok in doc:
          if tok.ent_type_ == "":
              df.append([sidx, tok.text, "O"])
          else:
              df.append([sidx, tok.text, tok.ent_type_])

  df = pd.DataFrame(df, columns=["sentence_id", "words", "labels"])
  return df


def transform_test(all_labels):
    docs = load_data_split("test", "UD_Danish-DDT", all_labels)
    df = []

    for sidx, doc in enumerate(docs):
        for tok in doc:
            if tok.ent_type_ == "":
                df.append([sidx, tok.text, "O"])
            else:
                df.append([sidx, tok.text, tok.ent_type_])
    df = pd.DataFrame(df, columns=["sentence_id", "words", "labels"])
    return df

# Tag the training data with the HMM and MV
train_docs = tag_all(train_docs, [mv, hmm])

# Transform the training and test data into correct format
df_train = transform_train(train_docs, aggregation_model="mv")
df_test = transform_test(all_labels)

# Write to csv
df_train.to_csv("train.csv", sep=';', index=None)
df_test.to_csv("test.csv", sep=';', index=None)

# %% [markdown]
# #### Train Classifier

# %%
from simpletransformers.ner import NERModel

# Create a NERModel
model = NERModel(
    "bert",
    "bert-base-cased",
    use_cuda=False,
    labels=df_train.labels.unique().tolist(),
    args={"overwrite_output_dir": True, "reprocess_input_data": True, "train_batch_size": 64},
)

# # Train the model
model.train_model(df_train)

# # Evaluate the model
result, model_outputs, predictions = model.eval_model(df_test)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/69 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/71 [00:00<?, ?it/s]
# /Users/agmo/projects/phd_courses/weak_supervision_tutorial/.venv/lib/python3.11/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /Users/agmo/projects/phd_courses/weak_supervision_tutorial/.venv/lib/python3.11/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /Users/agmo/projects/phd_courses/weak_supervision_tutorial/.venv/lib/python3.11/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /Users/agmo/projects/phd_courses/weak_supervision_tutorial/.venv/lib/python3.11/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /Users/agmo/projects/phd_courses/weak_supervision_tutorial/.venv/lib/python3.11/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
result
# Out:
# {'eval_loss': 1.3793464252646541,
#  'precision': 0.41172741679873215,
#  'recall': 0.38329890823251694,
#  'f1_score': 0.3970048899755501}

# %% [markdown]
# ## Evaluation
#
# We see from the evaluation metrics above, that the BERT-based model performs worse than MV and HMM, achieving a micro F1 score of 0.392. This is, however, not surprising as our labels in the training data is based on the MV, which itself does not perform well in regards to a micro F1 of 0.424. Oppositely, it is noteworthy that the BERT model doesn't manage to use the extensive language understanding from the pre-training, prior to this task-specific fine-tuning. This might be attributed to the lack of Danish data in the initial pre-training.
#
# This result highlights the need for high quality labels when fine-tuning a model. For this particular case, we would need additional and perhaps more complicated heuristics to obtain more accurate weak labels.
